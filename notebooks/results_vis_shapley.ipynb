# %%
import ast

import matplotlib.pyplot as plt

# %%
model1_path = '../results/results_our_bad_model_shapley.txt'
model2_path = '../results/results_ours_good_model_global_importance_values.txt'

# %%
with open(model1_path, 'r') as f:
    lines = ''.join(f.readlines())

lines = ast.literal_eval(lines)

# %%
lines
# Out:
# {'pla_historie_ontwikkeling': 0.029641802520726436,
#  'instrument_ladder_huidig_activering': 0.02283399550917766,
#  'ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden': 0.016478670382887695,
#  'contacten_onderwerp_no_show': 0.016331336664343457,
#  'relatie_overig_actueel_vorm__kostendeler': 0.012562079436095573,
#  'instrument_reden_beeindiging_historie_succesvol': 0.0125215448723202,
#  'adres_aantal_verzendadres': 0.0116483556474377,
#  'pla_hist_pla_categorie_doelstelling_16': 0.010541945617425537,
#  'persoonlijke_eigenschappen_dagen_sinds_taaleis': 0.01024487706948884,
#  'persoonlijke_eigenschappen_dagen_sinds_opvoer': 0.009974730001674769,
#  'contacten_soort_afgelopenjaar_document__uitgaand_': 0.008959129782154442,
#  'persoon_geslacht_vrouw': 0.008878538860952127,
#  'relatie_overig_historie_vorm__andere_inwonende': 0.008202425472534771,
#  'persoonlijke_eigenschappen_taaleis_voldaan': 0.007954923680543997,
#  'belemmering_dagen_financiele_problemen': 0.00794006850748812,
#  'relatie_overig_kostendeler': 0.007818385238737575,
#  'instrument_ladder_historie_activering': 0.00705397879581543,
#  'ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie': 0.0070148927156832375,
#  'belemmering_dagen_lichamelijke_problematiek': 0.007001070241878071,
#  'deelname_act_actueel_projecten_uniek': 0.006158397450366241,
#  'competentie_vakdeskundigheid_toepassen': 0.0059006872281456724,
#  'beschikbaarheid_aantal_historie_afwijkend_wegens_medische_omstandigheden': 0.005647641864625878,
#  'typering_ind': 0.0055163566014740945,
#  'afspraak_inspanningsperiode': 0.005284982951013357,
#  'relatie_partner_totaal_dagen_partner': 0.005084740372461064,
#  'belemmering_aantal_huidig': 0.004914344884288951,
#  'afspraak_resultaat_ingevuld_uniek': 0.004860570406811877,
#  'contacten_soort_document__uitgaand_': 0.004859320391841894,
#  'afspraak_signaal_voor_medewerker': 0.004731700477277136,
#  'persoonlijke_eigenschappen_uitstroom_verw_vlgs_km': 0.004541351235395461,
#  'belemmering_dagen_psychische_problemen': 0.004452021639553961,
#  'relatie_kind_leeftijd_verschil_ouder_eerste_kind': 0.004438862404183064,
#  'contacten_soort_afgelopenjaar_e_mail__uitgaand_': 0.0043528273566595145,
#  'contacten_onderwerp_overleg_met_inkomen': 0.0042343769618462465,
#  'relatie_kind_huidige_aantal': 0.004225747461986649,
#  'afspraak_aantal_woorden': 0.0041794702119773465,
#  'pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige': 0.004127869036743838,
#  'ontheffing_dagen_hist_mean': 0.004126546554193065,
#  'adres_dagen_op_adres': 0.004074656898568842,
#  'typering_dagen_som': 0.0035579516372822606,
#  'afspraak_laatstejaar_aantal_woorden': 0.003531200033156902,
#  'contacten_soort_afgelopenjaar_anders': 0.0034621268451675504,
#  'contacten_soort_document__inkomend_': 0.0034465527541621965,
#  'contacten_onderwerp_financiÃ«le_situatie': 0.003349910727680025,
#  'contacten_soort_anders': 0.0032762369899301024,
#  'belemmering_ind_hist': 0.0032250163840472556,
#  'persoonlijke_eigenschappen_spreektaal': 0.003140127895675006,
#  'relatie_overig_actueel_vorm_other': 0.003133522113624132,
#  'pla_ondertekeningen_historie': 0.0029903459106161356,
#  'adres_aantal_brp_adres': 0.002926902527309065,
#  'contacten_onderwerp_documenttype__overeenkomst_': 0.0026916414926222796,
#  'contacten_onderwerp_beoordelen_taaleis': 0.0026350495588186463,
#  'persoonlijke_eigenschappen_opstelling': 0.002633571935045399,
#  'contacten_soort_telefoontje__inkomend_': 0.0025842057897583395,
#  'contacten_onderwerp_boolean_contact_met_aanbieder': 0.002567948713934255,
#  'ontheffing_actueel_ind': 0.002534384820992745,
#  'contacten_soort_e_mail__uitgaand_': 0.0025102656573752066,
#  'contacten_onderwerp_ziek__of_afmelding': 0.00249418388247699,
#  'relatie_kind_jongvolwassen': 0.002459074177943624,
#  'contacten_onderwerp_boolean_no_show': 0.0024056488739456258,
#  'contacten_soort_gesprek_op_locatie': 0.0023293787231736555,
#  'persoonlijke_eigenschappen_uitstroom_verw_vlgs_klant': 0.0022026516544716244,
#  'pla_einde_doelstelling_bereikt__nieuw_trajectplan': 0.0021817993575499756,
#  'contacten_soort_e_mail__inkomend_': 0.002178268737256306,
#  'pla_ondertekeningen_actueel': 0.0021763433130546203,
#  'contacten_onderwerp_matching': 0.002151891877777445,
#  'afspraak_laatstejaar_resultaat_ingevuld_uniek': 0.0020937851592504105,
#  'contacten_onderwerp_documenten__innemen_': 0.002089606677776047,
#  'competentie_kwaliteit_leveren': 0.0020108432755888907,
#  'contacten_onderwerp__arbeids_motivatie': 0.0019766345162404975,
#  'pla_hist_pla_categorie_doelstelling_4': 0.0019562790635878533,
#  'contacten_soort_afgelopenjaar_e_mail__inkomend_': 0.0019143831600791053,
#  'contacten_soort_rapportage_rib': 0.001913474065880081,
#  'persoonlijke_eigenschappen_leergierigheid_opm': 0.0018965628447278155,
#  'contacten_onderwerp__werk_intake': 0.0018433403831997499,
#  'afspraak_laatstejaar_resultaat_ingevuld': 0.0017994650149303526,
#  'contacten_onderwerp_inspanningstoets': 0.0017915799989918386,
#  'contacten_onderwerp_zorg': 0.0017852497351086864,
#  'persoonlijke_eigenschappen_nl_schrijven0': 0.0017752735766829429,
#  'contacten_onderwerp_traject': 0.0017663327224718148,
#  'contacten_soort_afgelopenjaar_telefoontje__uitgaand_': 0.0017652375150464424,
#  'afspraak_other': 0.0017622613424695443,
#  'belemmering_psychische_problemen': 0.0017523199252837034,
#  'contacten_onderwerp__pre__intake': 0.0017292966363518071,
#  'belemmering_ind': 0.0017035816597872327,
#  'afspraak_afgelopen_jaar_voortgang_aanmelding_en_deelname': 0.001702050894229984,
#  'persoonlijke_eigenschappen_spreektaal_anders': 0.0016963045862378422,
#  'contacten_onderwerp_overige': 0.001689745530134536,
#  'contacten_onderwerp_terugbelverzoek': 0.0016763951264663656,
#  'afspraak_afgelopen_jaar_signaal_voor_medewerker': 0.001621676421047079,
#  'competentie_other': 0.001586784891186718,
#  'deelname_act_reintegratieladder_ondersteunende_instrumenten': 0.0015764804209973376,
#  'afspraak_afsprakenplan': 0.0015642384914688898,
#  'pla_hist_pla_categorie_doelstelling_1': 0.0015589515580380904,
#  'persoonlijke_eigenschappen_ind_regulier_arbeidsritme': 0.0015587879097167055,
#  'contacten_onderwerp_contact_derden': 0.0015235185669101711,
#  'relatie_kind_tiener': 0.0014996566102844912,
#  'deelname_act_reintegratieladder_werk_re_integratie': 0.0014782149481677772,
#  'persoonlijke_eigenschappen_houding_opm': 0.0014694529920563685,
#  'afspraak_afgelopen_jaar_ontheffing_taaleis': 0.001455175574398641,
#  'contacten_onderwerp_boolean_uitnodiging': 0.0014512095070450635,
#  'pla_hist_pla_categorie_doelstelling_2': 0.0014347609336938442,
#  'contacten_soort_afgelopenjaar_document__inkomend_': 0.0014286214369577809,
#  'relatie_kind_basisschool_kind': 0.00141616585139523,
#  'afspraak_signaal_van_aanbieder': 0.0013849486790740184,
#  'instrument_reden_beeindiging_historie_doelstelling_bereikt__geen_uitstroom': 0.0013849005223199571,
#  'persoonlijke_eigenschappen_uiterlijke_verzorging_opm': 0.0013762989723891963,
#  'persoonlijke_eigenschappen_doorzettingsvermogen_opm': 0.00137240057051349,
#  'contacten_onderwerp_boolean__arbeids_motivatie': 0.0013705702231252617,
#  'instrument_reden_beeindiging_historie_uitval__aanbod_niet_langer_zinvol_volgens_gemeente': 0.0013642788241415554,
#  'contacten_soort_afgelopenjaar_gesprek': 0.0013623632997716406,
#  'persoonlijke_eigenschappen_presentatie_opm': 0.0013207817758572004,
#  'relatie_overig_historie_vorm__onderhoudsplichtige': 0.0013015647371635967,
#  'afspraak_afgelopen_jaar_afsprakenplan': 0.0012862984203964609,
#  'adres_recentste_buurt_other': 0.0012816210431714067,
#  'pla_hist_pla_categorie_doelstelling_6': 0.001241891174517684,
#  'contacten_onderwerp_boolean_ziek__of_afmelding': 0.0012204116955822446,
#  'beschikbaarheid_recent_afwijkend_wegens_medische_omstandigheden': 0.0012077084669220718,
#  'afspraak_galo_gesprek': 0.0012055031920041714,
#  'competentie_omgaan_met_verandering_en_aanpassen': 0.001183294388689645,
#  'deelname_act_hist_projecten_niet_gestart': 0.0011774491444110822,
#  'belemmering_hist_lichamelijke_problematiek': 0.0011742218797034904,
#  'contacten_onderwerp_uitnodiging': 0.0011705107880713654,
#  'afspraak_voortgangsgesprek': 0.0011566912495040473,
#  'contacten_soort_telefoontje__uitgaand_': 0.0011520763973062649,
#  'contacten_onderwerp_boolean_documenttype__overeenkomst_': 0.0011463470047921465,
#  'adres_aantal_verschillende_wijken': 0.0011206334855723516,
#  'relatie_overig_historie_vorm__gemachtigde': 0.0011162686133087802,
#  'contacten_onderwerp_contact_met_aanbieder': 0.0011126884535094333,
#  'contacten_soort_rapportage_deelname': 0.0011108104483747605,
#  'contacten_onderwerp_maatregel_overweging': 0.001110771576771948,
#  'persoonlijke_eigenschappen_taaleis_schrijfv_ok': 0.001106586686262546,
#  'persoonlijke_eigenschappen_motivatie_opm': 0.0010951374716027537,
#  'instrument_reden_beeindiging_historie_doelstelling_niet_bereikt__geen_uitstroom': 0.0010871222404854437,
#  'contacten_soort_afgelopenjaar_telefoontje__inkomend_': 0.001082171491569001,
#  'persoonlijke_eigenschappen_initiatief_opm': 0.0010804109449586885,
#  'persoonlijke_eigenschappen_zelfstandigheid_opm': 0.0010785109211137148,
#  'contacten_onderwerp_boolean_groepsbijeenkomst': 0.0010694677545936887,
#  'contacten_onderwerp_boolean_zorg': 0.0010632323859262674,
#  'persoonlijke_eigenschappen_communicatie_opm': 0.0010604113102712389,
#  'pla_hist_pla_categorie_doelstelling_3': 0.001058220075378609,
#  'afspraak_afgelopen_jaar_ontheffing': 0.0010570954849077768,
#  'pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan': 0.0010537238023176129,
#  'pla_historie_maatschappelijke_inspanning': 0.0010359470904460098,
#  'contacten_onderwerp_diagnosegesprek': 0.001031217163959941,
#  'persoon_leeftijd_bij_onderzoek': 0.0010254745555983813,
#  'persoonlijke_eigenschappen_flexibiliteit_opm': 0.0010146762788116443,
#  'contacten_onderwerp_boolean_contact_derden': 0.0010124582142591377,
#  'contacten_onderwerp_screening': 0.0010103461438435084,
#  'relatie_overig_historie_vorm__kostendeler': 0.0010022752677886935,
#  'competentie_samenwerken_en_overleggen': 0.0010016140795571084,
#  'pla_hist_pla_categorie_doelstelling_5': 0.0010010898971859615,
#  'persoonlijke_eigenschappen_ind_buiten_kantoortijden': 0.0009997543221374088,
#  'belemmering_hist_psychische_problemen': 0.0009962689531780103,
#  'ontheffing_reden_hist_medische_gronden': 0.000984598912093326,
#  'competentie_instructies_en_procedures_opvolgen': 0.0009775173086981619,
#  'adres_aantal_woonadres_handmatig': 0.0009640278095631767,
#  'persoonlijke_eigenschappen_nl_spreken2': 0.000964025898635867,
#  'competentie_plannen_en_organiseren': 0.000951941607449453,
#  'contacten_onderwerp_scholing': 0.0009488296076687224,
#  'instrument_aantal_laatstejaar': 0.0009472421066896349,
#  'afspraak_verzenden_beschikking_i_v_m__niet_voldoen_aan_wet_taaleis': 0.0009346811952798619,
#  'adres_recentste_wijk_feijenoord': 0.0009007211495539839,
#  'competentie_materialen_en_middelen_inzetten': 0.000899699924154633,
#  'afspraak_aanmelding_afgesloten': 0.000874575281764811,
#  'relatie_kind_volwassen': 0.0008437131827959626,
#  'afspraak_gespr__einde_zoekt___galo_gesprek_': 0.0008384790972509322,
#  'persoonlijke_eigenschappen_ind_activering_traject': 0.000827362185159391,
#  'contacten_onderwerp_inkomen': 0.0007932764012493938,
#  'competentie_formuleren_en_rapporteren': 0.0007897220551174802,
#  'afspraak_controle_aankondiging_maatregel': 0.0007772651401691886,
#  'pla_einde_doelstelling_bereikt': 0.0007597519332636118,
#  'contacten_onderwerp_documenttype__cv_': 0.0007580224186542542,
#  'pla_hist_pla_categorie_doelstelling_other': 0.0007493989106179019,
#  'belemmering_hist_verslavingsproblematiek': 0.0007461717773405616,
#  'afspraak_afgelopen_jaar_plan_van_aanpak': 0.0007349933197934146,
#  'typering_hist_aantal': 0.0007282531225429531,
#  'ontheffing_reden_hist_vanwege_uw_sociaal_maatschappelijke_situatie': 0.0007258499353575978,
#  'instrument_reden_beeindiging_historie_niet_succesvol': 0.0007237257455284605,
#  'instrument_ladder_historie_other': 0.0007237244218057436,
#  'afspraak_controle_verwijzing': 0.0007018851443351558,
#  'typering_other': 0.0006985092745629524,
#  'afspraak_participatietrede_vervolgmeting': 0.0006841431484567921,
#  'adres_recentste_wijk_delfshaven': 0.0006832889576843575,
#  'pla_einde_doelstelling_niet_bereikt__overdracht': 0.0006713323842072227,
#  'instrument_reden_beeindiging_historie_other': 0.0006601983327287632,
#  'contacten_onderwerp_boolean_terugbelverzoek': 0.0006449482344695578,
#  'relatie_overig_actueel_vorm__onderhoudsplichtige': 0.00063811732098696,
#  'contacten_onderwerp_boolean_documenttype__cv_': 0.000635606877196776,
#  'instrument_reden_beeindiging_historie_centrale_actie_wigo4it': 0.0006270985847979492,
#  'contacten_onderwerp_boolean_inkomen': 0.0006109066126888079,
#  'competentie_met_druk_en_tegenslag_omgaan': 0.0006102414325072696,
#  'pla_einde_doelstelling_niet_bereikt': 0.0005737531720520544,
#  'beschikbaarheid_aantal_historie_afwijkend_wegens_sociaal_maatschappelijke_situatie': 0.0005734764579214137,
#  'instrument_reden_beeindiging_historie_overdracht_succesvol': 0.0005701157246323004,
#  'contacten_onderwerp_boolean_overige': 0.0005693709358598155,
#  'contacten_onderwerp_groepsbijeenkomst': 0.0005679804586363362,
#  'contacten_onderwerp_arbeidsdiagnose_dariuz': 0.0005513792383194365,
#  'relatie_kind_heeft_kinderen': 0.0005465798119891783,
#  'pla_historie_other': 0.0005410415099195726,
#  'typering_aantal': 0.0005407594279083763,
#  'contacten_onderwerp_boolean__werk_intake': 0.0005381986427396058,
#  'afspraak_toevoegen_inschrijving_uwvwb': 0.0005309889748204256,
#  'competentie_overtuigen_en_beÃ¯nvloeden': 0.0005303113737980074,
#  'contacten_onderwerp_boolean_traject': 0.0005261103400256752,
#  'afspraak_deelname_compleet_uit_webapplicatie': 0.0005203516354793575,
#  'contacten_soort_afgelopenjaar_rapportage_rib': 0.0005202200173016166,
#  'competentie_analyseren': 0.0005193577512247183,
#  'adres_recentste_wijk_prins_alexa': 0.0005146162684203899,
#  'ontheffing_reden_hist_sociale_gronden': 0.0005127977489463443,
#  'contacten_onderwerp_boolean_documenttype__diploma_s_en_certificaten_': 0.0005053628220775068,
#  'instrument_ladder_huidig_other': 0.0004918438980960721,
#  'competentie_aansturen': 0.00048266295511673984,
#  'contacten_onderwerp_mutatie': 0.000462480650034116,
#  'typering_hist_inburgeringsbehoeftig': 0.000462276701561377,
#  'instrument_ladder_huidig_werk_re_integratie': 0.000457349727775313,
#  'pla_hist_pla_categorie_doelstelling_9': 0.00045556324282796496,
#  'pla_actueel_pla_categorie_doelstelling_9': 0.00045524222684189885,
#  'beschikbaarheid_recent_afwijkend_wegens_sociaal_maatschappelijke_situatie': 0.00044737066998563543,
#  'belemmering_financiele_problemen': 0.0004394018499952224,
#  'contacten_onderwerp_boolean_overleg_met_inkomen': 0.0004373866103671201,
#  'contacten_onderwerp_quickscan': 0.00043737228879729337,
#  'persoonlijke_eigenschappen_hobbies_sport': 0.00043692807308214613,
#  'persoonlijke_eigenschappen_nl_schrijven2': 0.0004356685870414738,
#  'competentie_gedrevenheid_en_ambitie_tonen': 0.00043131761388568265,
#  'afspraak_vervolgmeting_matchbaarheid_werkzoekende_klant': 0.0004107572779411988,
#  'instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_overig': 0.0004071659214448331,
#  'competentie_op_de_behoeften_en_verwachtingen_van_de__klant__richten': 0.00039079393944538234,
#  'contacten_onderwerp_boolean__pre__intake': 0.0003904998948100996,
#  'competentie_onderzoeken': 0.00037821352622365695,
#  'pla_einde_other': 0.0003735052682110769,
#  'contacten_soort_groepsbijeenkomsten': 0.0003577315219165618,
#  'instrument_reden_beeindiging_historie_overdracht_naar_mo': 0.00035712004357963604,
#  'contacten_onderwerp_werkintake__niet_verschenen': 0.0003556821245583243,
#  'contacten_onderwerp_boolean_maatregel_overweging': 0.00035487820836062334,
#  'pla_einde_geplande_einddatum_overschreden_zonder_nader_bericht': 0.0003499017907882489,
#  'contacten_onderwerp_boolean_financiÃ«le_situatie': 0.0003458507604469081,
#  'instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod': 0.0003450262388284916,
#  'instrument_reden_beeindiging_historie_niet_matchbaar': 0.00032900299474035655,
#  'relatie_overig_actueel_vorm__gemachtigde': 0.0003197679029799473,
#  'contacten_onderwerp_boolean_documenten__innemen_': 0.0003192890101504667,
#  'contacten_onderwerp_boolean_matching': 0.0003121529217759628,
#  'contacten_onderwerp_boolean_beoordelen_taaleis': 0.00031119728983089093,
#  'pla_hist_pla_categorie_doelstelling_11': 0.0003073899854438223,
#  'contacten_onderwerp_boolean_scholing': 0.0002988651498408613,
#  'competentie_ethisch_en_integer_handelen': 0.00029826953533057293,
#  'pla_hist_pla_categorie_doelstelling_10': 0.0002972778536937397,
#  'contacten_onderwerp_vakantie': 0.0002962572395594685,
#  'pla_einde_doelstelling_bereikt__overdracht': 0.00028982342844799955,
#  'adres_recentst_onderdeel_rdam': 0.0002815997283526734,
#  'instrument_reden_beeindiging_historie_op_termijn_matchbaar': 0.00027899685098504274,
#  'pla_historie_werk': 0.0002782439337134062,
#  'persoonlijke_eigenschappen_overige_opmerkingen': 0.00026554557017414087,
#  'contacten_onderwerp_boolean_diagnosegesprek': 0.00025851571892698106,
#  'relatie_partner_aantal_partner___partner__gehuwd_': 0.0002566021906587518,
#  'beschikbaarheid_huidig_bekend': 0.0002449166598427466,
#  'contacten_onderwerp_inname_aanvraag': 0.00024120372138578634,
#  'pla_actueel_pla_categorie_doelstelling_16': 0.00023085736661114775,
#  'competentie_leren': 0.00021645011766859175,
#  'contacten_onderwerp_boolean_taaleis___voldoet': 0.00021044682066395247,
#  'persoonlijke_eigenschappen_nl_spreken1': 0.0001939606218088359,
#  'adres_recentste_wijk_other': 0.00019378300413019835,
#  'afspraak_afgelopen_jaar_vervolgmeting_matchbaarheid_werkzoekende_klant': 0.00019342388544877032,
#  'pla_hist_pla_categorie_doelstelling_27': 0.00018183035750965316,
#  'ontheffing_reden_hist_other': 0.00017402009658348773,
#  'persoonlijke_eigenschappen_nl_schrijven1': 0.00016670273444998284,
#  'instrument_reden_beeindiging_historie_overdracht_naar_prematching': 0.0001538241845092218,
#  'belemmering_hist_stabiele_mix__sz____dagbesteding_werk': 0.00015340372712034566,
#  'adres_recentste_plaats_rotterdam': 0.0001498112274831131,
#  'pla_historie_werk_en_inburgering': 0.00014974924921593713,
#  'persoonlijke_eigenschappen_nl_begrijpen3': 0.00014379659916714587,
#  'adres_unieke_wijk_ratio': 0.00013015989392691684,
#  'instrument_reden_beeindiging_historie_diagnose_gesteld': 0.00012172577850593099,
#  'adres_recentste_wijk_charlois': 0.00011961578074193107,
#  'belemmering_hist_taal': 0.00010732082482671926,
#  'contacten_soort_afgelopenjaar_gesprek_op_locatie': 0.00010624953039909811,
#  'instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_naar_regulier_werk': 0.00010265571440512223,
#  'relatie_overig_actueel_vorm__ouders_verzorgers': 9.873061769045344e-05,
#  'ontheffing_reden_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie': 8.924380661734499e-05,
#  'persoonlijke_eigenschappen_nl_spreken3': 7.648687553617564e-05,
#  'relatie_partner_aantal_partner___partner__ongehuwd_': 7.613207429639946e-05,
#  'typering_indicatie_geheime_gegevens': 7.24320644484186e-05,
#  'instrument_reden_beeindiging_historie_direct_matchbaar': 7.192774154827282e-05,
#  'relatie_partner_huidige_partner___partner__gehuwd_': 7.183086958347587e-05,
#  'adres_recentste_wijk_ijsselmonde': 7.09713993722452e-05,
#  'persoonlijke_eigenschappen_nl_lezen3': 6.893291074035322e-05,
#  'adres_recentste_wijk_kralingen_c': 6.378608871710483e-05,
#  'persoonlijke_eigenschappen_nl_schrijven3': 6.334530470299677e-05,
#  'contacten_onderwerp_boolean_match___werk': 5.337823107029973e-05,
#  'instrument_reden_beeindiging_historie_niet_succesvol__reden_bij_werkzoekende': 5.030023218764258e-05,
#  'contacten_onderwerp_boolean_sollicitatie': 4.641923363009026e-05,
#  'beschikbaarheid_huidig_afwijkend_wegens_medische_omstandigheden': 4.2323465502426646e-05,
#  'ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverplichtingen': 3.376947260162089e-05,
#  'contacten_onderwerp_boolean_motivatie': 2.9741912737367334e-05,
#  'contacten_onderwerp_boolean_mutatie': 2.533249805745566e-05,
#  'instrument_reden_beeindiging_historie_succesvol__doelstelling_bereikt': 2.4160650080166126e-05,
#  'persoonlijke_eigenschappen_nl_lezen4': 2.2252361744620834e-05,
#  'afspraak_afgelopen_jaar_monitoring_insp__wet_taaleis_na_12_mnd_n_a_v__taa04_____geen_maatregel': 2.023275669135742e-05,
#  'adres_recentste_wijk_noord': 1.9208258118030865e-05,
#  'typering_transport__logistiek___tuinbouw': 1.7805976435503572e-05,
#  'belemmering_niet_computervaardig': 1.7072304458735446e-05,
#  'instrument_reden_beeindiging_historie_overdracht_naar_regulier_team_iwpm': 1.5017713382808762e-05,
#  'typering_zorg__schoonmaak___welzijn': 1.4670236922715625e-05,
#  'typering_hist_sector_zorg': 1.1556538271233396e-05,
#  'belemmering_woonsituatie': 9.294818731034679e-06,
#  'adres_recentste_buurt_vreewijk': 6.319173022790328e-06,
#  'adres_recentste_wijk_stadscentru': 5.6828757973962755e-06,
#  'adres_recentste_plaats_other': 4.5224414837795404e-06,
#  'relatie_overig_bewindvoerder': 4.486141714872661e-06,
#  'persoonlijke_eigenschappen_nl_schrijvenfalse': 2.443554671638236e-06,
#  'adres_recentste_buurt_groot_ijsselmonde': 2.2726460427662764e-06,
#  'adres_recentste_buurt_nieuwe_westen': 1.639794498591833e-06,
#  'adres_recentste_buurt_oude_noorden': 0.0,
#  'ontheffing_hist_ind': 0.0,
#  'typering_hist_ind': 0.0}

# %%
names = [key for key, _ in lines.items()][:30]
values = [value for __, value in lines.items()][:30]

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.barh(names, values, color='dodgerblue', zorder=2)

ax.set_xlabel("Shapley Values")
ax.set_title('Bad model Shapley Value Results for 15 Most Important Features')

ax.invert_yaxis()
ax.grid(axis='x', zorder=0)

fig.tight_layout()

fig.savefig("../figures/bad_model_shapley.png")

# %%
with open(model2_path, 'r') as f:
    model2 = ''.join(f.readlines())

model2 = ast.literal_eval(model2)

model2_top_features = model2[:15]

names2 = [tup[0] for tup in model2_top_features]
values2 = [tup[1] for tup in model2_top_features]

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.barh(names2, values2, color='dodgerblue', zorder=2)

ax.set_xlabel("Feature Importance")
ax.set_title('Model 2 Metamorphic Testing Results for 15 Most Important Features')

ax.invert_yaxis()
ax.grid(axis='x', zorder=0)

fig.tight_layout()

fig.savefig("../figures/model2_metamorphic.png")
